# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import glob

path = r'C:\Users\mohit\Downloads' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   del sys.path[0]

# %%
data.describe()
# Out:
#                Beat  Community Area      District            ID          Id  \
# count  1.048575e+06   433758.000000  1.048575e+06  1.048575e+06  150.000000
# mean   1.223086e+03       37.056029  1.136983e+01  1.986269e+06   75.500000
# std    7.096380e+02       21.509026  6.992544e+00  4.740337e+05   43.445368
# min    1.110000e+02        0.000000  1.000000e+00  6.340000e+02    1.000000
# 25%    6.240000e+02       23.000000  6.000000e+00  1.649160e+06   38.250000
# 50%    1.121000e+03       32.000000  1.000000e+01  1.977641e+06   75.500000
# 75%    1.821000e+03       56.000000  1.700000e+01  2.304970e+06  112.750000
# max    2.535000e+03       77.000000  2.500000e+01  1.053707e+07  150.000000
#
#            Latitude     Longitude  PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# count  1.027938e+06  1.027938e+06     150.000000    150.000000     150.000000
# mean   4.184501e+01 -8.767163e+01       3.758667      1.198667       5.843333
# ...

# %%
data['Primary Type'].unique()
# Out:
# array(['THEFT', 'OTHER OFFENSE', 'OFFENSE INVOLVING CHILDREN',
#        'CRIM SEXUAL ASSAULT', 'MOTOR VEHICLE THEFT', 'SEX OFFENSE',
#        'DECEPTIVE PRACTICE', 'BATTERY', 'BURGLARY', 'WEAPONS VIOLATION',
#        'PUBLIC PEACE VIOLATION', 'NARCOTICS', 'GAMBLING', 'PROSTITUTION',
#        'LIQUOR LAW VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'CRIMINAL DAMAGE', 'ASSAULT', 'STALKING', 'ARSON',
#        'CRIMINAL TRESPASS', 'HOMICIDE', 'ROBBERY', 'OBSCENITY',
#        'KIDNAPPING', 'INTIMIDATION', 'RITUALISM', 'DOMESTIC VIOLENCE',
#        'OTHER NARCOTIC VIOLATION', 'PUBLIC INDECENCY', nan], dtype=object)

# %%
labels=list(data['Primary Type'].unique())

# %%
data['District'].unique()
# Out:
# array([ 4.,  9., 14., 25., 22., 10.,  5., 18., 11., 20.,  8.,  7.,  1.,
#        16., 15.,  3.,  6.,  2., 19., 12., 24., 17., nan])

# %%
data['Year'].unique()
# Out:
# array([2004., 2003., 2001., 2002.,   nan])

# %%
data.nunique()
# Out:
# Arrest                        2
# Beat                        296
# Block                     53304
# Case Number             1048495
# Community Area               78
# Date                     408723
# Description                 314
# District                     22
# Domestic                      2
# FBI Code                     26
# ID                      1048575
# IUCR                        335
# Id                          150
# Latitude                 425094
# Location                 428134
# Location Description        141
# Longitude                423811
# PetalLengthCm                43
# PetalWidthCm                 22
# Primary Type                 30
# SepalLengthCm                35
# SepalWidthCm                 23
# Species                       3
# Updated On                  357
# Ward                         50
# X Coordinate              71456
# Y Coordinate             118198
# Year                          4
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Arrest                      150
# Beat                        150
# Block                       150
# Case Number                 150
# Community Area           614967
# Date                        150
# Description                 150
# District                    150
# Domestic                    150
# FBI Code                    150
# ID                          150
# IUCR                        150
# Id                      1048575
# Latitude                  20787
# Location                  20787
# Location Description        157
# Longitude                 20787
# PetalLengthCm           1048575
# PetalWidthCm            1048575
# Primary Type                150
# SepalLengthCm           1048575
# SepalWidthCm            1048575
# Species                 1048575
# Updated On                  150
# Ward                     614917
# X Coordinate              20787
# Y Coordinate              20787
# Year                        150
# dtype: int64

# %%
data.shape
# Out:
# (1048725, 28)

# %%
data['Primary Type'].value_counts()
# Out:
# THEFT                               212362
# BATTERY                             201429
# CRIMINAL DAMAGE                     120182
# NARCOTICS                           111094
# OTHER OFFENSE                        68164
# ASSAULT                              67525
# MOTOR VEHICLE THEFT                  56454
# BURGLARY                             55793
# ROBBERY                              39654
# DECEPTIVE PRACTICE                   30420
# CRIMINAL TRESPASS                    29910
# PROSTITUTION                         13420
# WEAPONS VIOLATION                     9268
# PUBLIC PEACE VIOLATION                5610
# OFFENSE INVOLVING CHILDREN            5236
# SEX OFFENSE                           4744
# CRIM SEXUAL ASSAULT                   3907
# LIQUOR LAW VIOLATION                  3257
# ARSON                                 2190
# HOMICIDE                              2070
# GAMBLING                              1981
# KIDNAPPING                            1859
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='Primary Type',data=data)
plt.title('Crims count')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(y='Year',data=data)
plt.title('Crimes count')
plt.show()

# %%
plt.figure(figsize=(30,150))
sns.countplot(y='Location Description',data=data,order = data['Location Description'].value_counts().index)
plt.title('Red Zones')
plt.show()

# %%
data['District'].unique()
# Out:
# array([ 4.,  9., 14., 25., 22., 10.,  5., 18., 11., 20.,  8.,  7.,  1.,
#        16., 15.,  3.,  6.,  2., 19., 12., 24., 17., nan])

# %%
data['District'].value_counts()
# Out:
# 2.0     70502
# 8.0     68589
# 11.0    62028
# 25.0    60310
# 7.0     59066
# 4.0     55024
# 6.0     54857
# 12.0    53460
# 9.0     52531
# 3.0     51574
# 19.0    49132
# 14.0    48312
# 18.0    48201
# 5.0     44283
# 15.0    43787
# 10.0    42106
# 16.0    34747
# 22.0    32939
# 1.0     32899
# 24.0    32393
# 17.0    31262
# 20.0    20573
# Name: District, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.countplot(y='District',data=data,order = data['District'].value_counts().index)
plt.title('total crimes')
plt.show()

# %%
p2=data[data['District']==20]['Block']

# %%
p2.value_counts()
# Out:
# 053XX N BROADWAY               380
# 050XX N WINTHROP AV            307
# 048XX N BROADWAY               280
# 050XX N SHERIDAN RD            273
# 048XX N WINTHROP AV            267
# 052XX N SHERIDAN RD            260
# 049XX N WINTHROP AV            223
# 048XX N SHERIDAN RD            220
# 057XX N WINTHROP AV            204
# 048XX N CLARK ST               165
# 048XX N FRANCISCO AV           164
# 057XX N SHERIDAN RD            162
# 010XX W ARGYLE ST              159
# 058XX N SHERIDAN RD            159
# 055XX N CLARK ST               156
# 054XX N SHERIDAN RD            144
# 011XX W ARGYLE ST              133
# 051XX N DAMEN AV               132
# 050XX N WINTHROP AVE           130
# 056XX N BROADWAY               117
# 054XX N BROADWAY               114
# 049XX N SHERIDAN RD            113
# 019XX W LAWRENCE AV            110
# 057XX N BROADWAY               108
# 051XX N DAMEN AVE              107
# 010XX W HOLLYWOOD AV           106
# 048XX N WINTHROP AVE           103
# ...

# %%
plt.figure(figsize=(30,850))
sns.countplot(y=p2,data=data,order = p2.value_counts().index)
plt.title('total crimes')
plt.show()

# %%
p3=data[data['Block']=='053XX N BROADWAY']['Location Description']

# %%
plt.figure(figsize=(10,20))
sns.countplot(y=p3,data=data,order = p3.value_counts().index)
plt.title('total crimes')
plt.show()
